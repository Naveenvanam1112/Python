# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
df=pd.read_csv("/content/titanic (1).csv")
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# replacing cabin feature null values with forward values
import warnings
warnings.filterwarnings('ignore')
df['Cabin']=df['Cabin'].fillna(method='ffill')

# %%
#calculating the null values in cabin feature
df['Cabin'].isnull().sum()
# Out:
# 1

# %%
#replacing that one null value backward value in cabin feature
df['Cabin']=df['Cabin'].fillna(method='bfill')
df['Cabin'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %%
# calculating mean value for age feature
mean=df['Age'].mean()
mean
# Out:
# 29.69911764705882

# %%
# replacing nan values with mean of Age
import numpy as np
df['Age']=df['Age'].replace(np.NaN,mean)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
# replacing embarked  feature null values with forward values
df['Embarked']=df['Embarked'].fillna(method='ffill')

# %%
df['Embarked'].isnull().sum()
# Out:
# 0

# %%
# there are no null values in the dataset
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# changing the age data type from float to int
df['Age']=df['Age'].astype('int')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
x=({'male':0,'female':1})
data['Sex']=data['Sex'].map(x)

# %%
data
# Out:
#      Survived  Pclass  Sex  Age     Fare
# 0           0       3    0   22   7.2500
# 1           1       1    1   38  71.2833
# 2           1       3    1   26   7.9250
# 3           1       1    1   35  53.1000
# 4           0       3    0   35   8.0500
# ..        ...     ...  ...  ...      ...
# 886         0       2    0   27  13.0000
# 887         1       1    1   19  30.0000
# 888         0       3    1   29  23.4500
# 889         1       1    0   26  30.0000
# 890         0       3    0   32   7.7500
#
# [891 rows x 5 columns]

# %%
# dropping the features that do not impact on survuval rate
data=df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis=1)

# %%
target=data['Survived']
inputs=data.drop(['Survived'],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2)
print(len(X_train), len(X_test), len(inputs))
# Out:
# 712 179 891

# %%
from sklearn.naive_bayes import GaussianNB
# fitting the model
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.6871508379888268

# %%
pred = np.array(model.predict(X_test))
pred_probability = np.array(model.predict_proba(X_test)) # calculating the probabilities

print(pred[:10])
print(pred_probability[:10])
# Out:
# [0 1 1 0 0 0 0 1 1 1]
# [[9.47498970e-01 5.25010304e-02]
#  [7.04609512e-08 9.99999930e-01]
#  [1.50262982e-01 8.49737018e-01]
#  [7.75578925e-01 2.24421075e-01]
#  [9.69875323e-01 3.01246775e-02]
#  [9.38035361e-01 6.19646394e-02]
#  [9.69192178e-01 3.08078218e-02]
#  [2.87294900e-01 7.12705100e-01]
#  [3.06637987e-01 6.93362013e-01]
#  [1.21265843e-02 9.87873416e-01]]
