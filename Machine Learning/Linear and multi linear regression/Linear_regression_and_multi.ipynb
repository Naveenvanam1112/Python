# %% [markdown]
# **LINEAR REGRESSION FOR SALARY DATA PREDICTION**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
salary=pd.read_csv("/content/Salary_Data.csv")
salary
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
salary.shape
# Out:
# (30, 2)

# %%
salary.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
x=salary.drop(['Salary'],axis=1)
y=salary['Salary']

# %%
print(x)
print(y)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# ...

# %%
# splitting the dataset
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (24, 1) (6, 1) (24,) (6,)

# %%
# model selection
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_train)
# Out:
# array([102863.7816125 ,  53101.92980825,  43532.34292281,  89466.35997289,
#         52144.9711197 , 116261.2032521 ,  62671.51669368,  45446.2602999 ,
#         61714.55800514,  73198.06226766, 122959.91407191, 110519.45112084,
#         75111.97964474,  38747.5494801 ,  55015.84718533, 115304.24456356,
#        107648.57505521,  80853.731776  ,  62671.51669368,  99992.90554687,
#        124873.83144899,  63628.47538222,  71284.14489057,  55015.84718533])

# %%
model.coef_
# Out:
# array([9569.58688543])

# %%
model.intercept_
# Out:
# 24393.169151948343

# %%
y_pred=model.predict(x_test)
x_pred=model.predict(x_train)
print(y_pred)
print("*"*20)
print(x_pred)
# Out:
# [36833.63210301 34919.71472592 67456.3101364  59800.64062805
#  92337.23603852 81810.69046455]
# ********************
# [102863.7816125   53101.92980825  43532.34292281  89466.35997289
#   52144.9711197  116261.2032521   62671.51669368  45446.2602999
#   61714.55800514  73198.06226766 122959.91407191 110519.45112084
#   75111.97964474  38747.5494801   55015.84718533 115304.24456356
#  107648.57505521  80853.731776    62671.51669368  99992.90554687
#  124873.83144899  63628.47538222  71284.14489057  55015.84718533]

# %%
plt.scatter(x_train,y_train,color='red',marker='*')
plt.plot(x_train,x_pred,color='blue')
plt.grid(True)
plt.xlabel('years of experience')
plt.ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %%
plt.scatter(x_test,y_test,color='red',marker='*')
plt.plot(x_train,x_pred,color='blue')
plt.grid(True)
plt.xlabel('years of experience')
plt.ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %%
# r squared  error
r_score=metrics.r2_score(y_train,y_pred)
r_score
# Out:
# 0.9669125058878869

# %%
n=len(salary)
n
# Out:
# 30

# %%
adjusted=1-(1-r_score)*((n-1)/(n-n-1))
adjusted
# Out:
# 2.001214640454156

# %%
mse=metrics.mean_squared_error(y_train,train_data)
mse
# Out:
# 25922093.28794687

# %% [markdown]
# **MULTI LINEAR REGRESSION FOR THE EXAMPLE**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
dataset={
    'x1':[5,6,7,8,9,4,6,8,7,5],
    'x2':[80,85,90,88,95,78,82,89,84,80],
    'x3':[2,3,3,4,2,1,1,2,3,4],
    'y':[75,80,85,90,92,65,70,87,83,78]
}
data=pd.DataFrame(dataset)
data
# Out:
#    x1  x2  x3   y
# 0   5  80   2  75
# 1   6  85   3  80
# 2   7  90   3  85
# 3   8  88   4  90
# 4   9  95   2  92
# 5   4  78   1  65
# 6   6  82   1  70
# 7   8  89   2  87
# 8   7  84   3  83
# 9   5  80   4  78

# %%
x=data.drop(['y'],axis=1)
y=data['y']
print(x)
print(y)
# Out:
#    x1  x2  x3
# 0   5  80   2
# 1   6  85   3
# 2   7  90   3
# 3   8  88   4
# 4   9  95   2
# 5   4  78   1
# 6   6  82   1
# 7   8  89   2
# 8   7  84   3
# 9   5  80   4
# 0    75
# 1    80
# 2    85
# 3    90
# 4    92
# 5    65
# 6    70
# 7    87
# 8    83
# 9    78
# Name: y, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_train)
print(y_pred)
# Out:
# [65.21740962 72.0667397  85.27134069 86.26443077 78.14106345 91.44097076
#  90.75629898 72.84174602]

# %%
model.predict([[6,85,2]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([77.6470043])

# %%
r2=metrics.r2_score(y_train,y_pred)
print("r2 is:>",r2)
# Out:
# r2 is:> 0.9669125058878869

# %%
coefficients = pd.DataFrame({'Feature': x.columns, 'Coefficient': model.coef_})
intercept = model.intercept_
print("\nModel Coefficients:\n", coefficients)
print(f'Intercept: {intercept:.2f}')
# Out:
# Model Coefficients:
#    Feature  Coefficient
# 0      x1     2.633437
# 1      x2     0.589365
# 2      x3     3.037162
# Intercept: 5.68

# %%
# for training
y_pred = model.predict(x_train)

print(y_pred)
plt.scatter(y_train, y_pred, color='blue')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='red', linestyle='--')
plt.xlabel('Actual Test Scores')
plt.ylabel('Predicted Test Scores')
plt.title('Actual vs Predicted Test Scores')
plt.grid(True)
plt.show()
# Out:
# [65.21740962 72.0667397  85.27134069 86.26443077 78.14106345 91.44097076
#  90.75629898 72.84174602]

# %%
# for testing

y_pred = model.predict(x_test)

print(y_pred)
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.xlabel('Actual Test Scores')
plt.ylabel('Predicted Test Scores')
plt.title('Actual vs Predicted Test Scores')
plt.grid(True)
plt.show()
# Out:
# [82.72823797 80.68416618]

# %% [markdown]
# **MULTI LINEAR REGRESSION FOR HOUSE PRICE PREDICTION**
#
# **predicting the price for the (3000,3,40) and (2500,4,5)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
house=pd.read_csv("/content/house multi linear.csv")
house
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
x=round(np.mean(house['bedrooms']))
x
# Out:
# 4

# %%
house['bedrooms']=house['bedrooms'].replace(np.NaN,x)

# %%
house.shape
# Out:
# (6, 4)

# %%
house.isnull().sum()
# Out:
# area        0
# bedrooms    0
# age         0
# price       0
# dtype: int64

# %%
house
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
x=house.drop(['price'],axis=1)
y=house['price']
print(x)
print(y)
# Out:
#    area  bedrooms  age
# 0  2600       3.0   20
# 1  3000       4.0   15
# 2  3200       4.0   18
# 3  3600       3.0   30
# 4  4000       5.0    8
# 5  4100       6.0    8
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
model.intercept_
# Out:
# 221323.00186540396

# %%
import warnings
warnings.filterwarnings("ignore")
train_data=model.predict([[3000,3,40]])
train_data
# Out:
# array([498408.25158031])

# %%
train_data=model.predict([[2500,4,5]])
train_data
# Out:
# array([578876.03748933])

# %% [markdown]
# **MULTI LINEAR REGRESSION FOR SALARY PREDICTION WITH EXPERIENCE AND TEST SCORES  [2,9,6] AND [12,10,10] FOR THESE INPUTS**

# %%
import pandas as pd
import numpy as np
dataset={
    'experience':[np.NaN,np.NaN,5,2,7,3,10,11],
    'test_score':[8,8,6,10,9,7,np.NaN,7],
    'interview_score':[9,6,7,10,6,10,7,8],
    'salary':[50000,45000,60000,65000,70000,62000,72000,80000]
}
data=pd.DataFrame(dataset)
data
# Out:
#    experience  test_score  interview_score  salary
# 0         NaN         8.0                9   50000
# 1         NaN         8.0                6   45000
# 2         5.0         6.0                7   60000
# 3         2.0        10.0               10   65000
# 4         7.0         9.0                6   70000
# 5         3.0         7.0               10   62000
# 6        10.0         NaN                7   72000
# 7        11.0         7.0                8   80000

# %%
data.isnull().sum()
# Out:
# experience         2
# test_score         1
# interview_score    0
# salary             0
# dtype: int64

# %%
import numpy as np
x=np.mean(data['experience'])
print(x)
# Out:
# 6.333333333333333

# %%
data['experience']=data['experience'].replace(np.NaN,x)

# %%
data
# Out:
#    experience  test_score  interview_score  salary
# 0    6.333333         8.0                9   50000
# 1    6.333333         8.0                6   45000
# 2    5.000000         6.0                7   60000
# 3    2.000000        10.0               10   65000
# 4    7.000000         9.0                6   70000
# 5    3.000000         7.0               10   62000
# 6   10.000000         NaN                7   72000
# 7   11.000000         7.0                8   80000

# %%
data['test_score']=data['test_score'].replace(np.NaN,np.mean(data['test_score']))

# %%
data
# Out:
#    experience  test_score  interview_score  salary
# 0    6.333333    8.000000                9   50000
# 1    6.333333    8.000000                6   45000
# 2    5.000000    6.000000                7   60000
# 3    2.000000   10.000000               10   65000
# 4    7.000000    9.000000                6   70000
# 5    3.000000    7.000000               10   62000
# 6   10.000000    7.857143                7   72000
# 7   11.000000    7.000000                8   80000

# %%
x=data.drop(['salary'],axis=1)
y=data['salary']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2633.0537639 , 1203.95910777, 2787.82004231])

# %%
model.intercept_
# Out:
# 14910.231291544944

# %%
model.predict([[2,9,6]])
# Out:
# array([47738.89104313])

# %%
model.predict([[12,10,10]])
# Out:
# array([86424.66795913])
